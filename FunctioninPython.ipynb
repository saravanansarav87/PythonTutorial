# %% [markdown]
# <a href="https://colab.research.google.com/github/saravanansarav87/PythonTutorial/blob/main/FunctioninPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet():
  print("Hello Function")

# %%
greet()
# Out:
# Hello Function

# %%
def greet(name):
  print("Hello Parameter "+name)

# %%
greet("Saravanan")
# Out:
# Hello Parameter Saravanan

# %%
def add_num(num1,num2):
  return num1+num2

# %%
sum=add_num(12,43)
print(sum)
# Out:
# 55
