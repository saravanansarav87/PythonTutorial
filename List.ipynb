# %% [markdown]
# <a href="https://colab.research.google.com/github/saravanansarav87/PythonTutorial/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tasks=['development','testing','monitoring']
print(tasks)
# Out:
# ['development', 'testing', 'monitoring']

# %%
print(tasks[2])
# Out:
# monitoring

# %%
tasks[2]='testing'
print(tasks)
# Out:
# ['development', 'testing', 'testing']

# %%
tasks.append('production')
print(tasks)
# Out:
# ['development', 'testing', 'testing', 'production']

# %%
tasks.insert(1,'unit testing')
print(tasks)
# Out:
# ['development', 'unit testing', 'testing', 'testing', 'production']

# %%
tasks.remove('unit testing')
print(tasks)
# Out:
# ['development', 'testing', 'testing', 'production']

# %%
tasks.pop(1)
print(tasks)
# Out:
# ['development', 'production']

# %%
for x in tasks:
    print(x)
# Out:
# development
# production
