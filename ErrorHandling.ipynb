# %% [markdown]
# <a href="https://colab.research.google.com/github/saravanansarav87/PythonTutorial/blob/main/ErrorHandling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(10/1)
# Out:
# 10.0

# %%
try:
  print(10/0)
except ZeroDivisionError:
  print("Sorry you are Dividing by Zero")
# Out:
# Sorry you are Dividing by Zero

# %%
try:
  print(10/0)
except:
  print("Sorry you are Dividing by Zero")
# Out:
# Sorry you are Dividing by Zero

# %%
from typing_extensions import final
try:
  print(10/2)
except:
  print("Sorry you are Dividing by Zero")
else:
  print("Nothing wrong happend")
finally:
  print("Execute always")
# Out:
# 5.0
# Nothing wrong happend
# Execute always

# %%
#reverse string
#This method is concise and generally considered the "Pythonic" way to reverse a string. The slice syntax [::-1] means "start at the beginning, go to the end, but step backward one element at a time".
def reverse_string(text):
    # Your code goes here.

    #result=text[::-1]
    #print(result)
    return text[::-1]

# %%
reverse_string("saravanan")
# Out:
# 'nanavaras'
