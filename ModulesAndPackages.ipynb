# %% [markdown]
# <a href="https://colab.research.google.com/github/saravanansarav87/PythonTutorial/blob/main/ModulesAndPackages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
print(math.sqrt(25))
# Out:
# 5.0

# %%
# !pip install pandas

# %%
import pandas as pd
data={'name':['John','Anna','Peter'],'Age':[34,23,43]}
df=pd.DataFrame(data)
print(df)
# Out:
#     name  Age
# 0   John   34
# 1   Anna   23
# 2  Peter   43
