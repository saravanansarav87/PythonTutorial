# %% [markdown]
# <a href="https://colab.research.google.com/github/saravanansarav87/PythonTutorial/blob/main/Tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Employee=(1232,"Saravanan","Chennai",52665545)
print(Employee)
# Out:
# (1232, 'Saravanan', 'Chennai', 52665545)

# %%
print(Employee[1])
# Out:
# Saravanan

# %%
print(len(Employee))
# Out:
# 4

# %%
print(Employee[-1])
# Out:
# 52665545

# %%
new_emp=list(Employee)
new_emp[1]="Saravanan Mayavan"
Employee=tuple(new_emp)
print(Employee)
# Out:
# (1232, 'Saravanan Mayavan', 'Chennai', 52665545)

# %%
for x in Employee:
  print(x)
# Out:
# 1232
# Saravanan Mayavan
# Chennai
# 52665545

# %%
print(Employee.index("Saravanan Mayavan"))
# Out:
# 1
