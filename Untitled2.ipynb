# %% [markdown]
# <a href="https://colab.research.google.com/github/saravanansarav87/PythonTutorial/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tasks={'Testing','Development','Auditing'}
print(tasks)
# Out:
# {'Development', 'Testing', 'Auditing'}

# %%
tasks={'Testing','Development','Auditing','Testing'}
print(tasks)
# Out:
# {'Development', 'Testing', 'Auditing'}

# %%
tasks.add('Deployment')
print(tasks)
# Out:
# {'Development', 'Testing', 'Deployment', 'Auditing'}

# %%
new_tasks={'SIT','UAT'}
tasks.update(new_tasks)
print(tasks)
# Out:
# {'SIT', 'Development', 'Auditing', 'Testing', 'Deployment', 'UAT'}

# %%
tasks.remove('SIT')
print(tasks)
# Out:
# {'Development', 'Auditing', 'Testing', 'Deployment', 'UAT'}

# %%
new_tasks.clear()
print(new_tasks)
# Out:
# set()
