# %% [markdown]
# <a href="https://colab.research.google.com/github/saravanansarav87/PythonTutorial/blob/main/Strings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
greeting="Hello data engineering!!"
print(greeting)
# Out:
# Hello data engineering!!

# %%
name="Saravanan"
message=greeting+name
print(message)
# Out:
# Hello data engineering!!Saravanan

# %%
new_string=greeting.replace("Hello","Hi")
print(new_string)
# Out:
# Hi data engineering!!

# %%
sentence='     Hello Saravanana   '
print(sentence)

print(sentence.strip())
# Out:
#      Hello Saravanana
# Hello Saravanana

# %%
index=greeting.find("data")
print(index)
# Out:
# 6

# %%
template="hello {}"
print(template.format("Saravanan"))
# Out:
# hello Saravanan

# %%
print(greeting.upper())
# Out:
# HELLO DATA ENGINEERING!!

# %%
print(greeting.lower())
# Out:
# hello data engineering!!

# %%
words=greeting.split()
print(words)
# Out:
# ['Hello', 'data', 'engineering!!']
